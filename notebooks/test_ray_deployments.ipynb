# %%
import requests
import os
from pathlib import Path

BASE_URL = "http://127.0.0.1:8000"
AUDIO_FILES_DIR = "../audio_files"

# Get all files in the audio_files directory
audio_dir = Path(AUDIO_FILES_DIR)
audio_files = list(audio_dir.glob("*"))

# Filter out directories if any
audio_files = [f for f in audio_files if f.is_file()]

print(f"Found {len(audio_files)} files to upload:")
for f in audio_files:
    print(f"  - {f.name}")
# Out:
# Found 3 files to upload:
#   - Furthest Thing.mp3
#   - Furthest Thing_piano_split_by_lalalai.m4a
#   - drake___drew_a_picasso_audio_synthesizer_split_by_lalalai.wav

# %%
files_list = []
for audio_file in audio_files:
    files_list.append(
        ("files", (audio_file.name, open(audio_file, "rb"), "audio/mpeg"))
    )

# Upload
response = requests.post(
    f"{BASE_URL}/v1/upload",
    files=files_list
)

# Clean up
for _, (_, file_handle, _) in files_list:
    file_handle.close()

print(f"Status: {response.status_code}")
print(f"Response: {response.text}")
# Out:
# Status: 200
# Response: null

# %%
import ray

ray.init(address="auto", ignore_reinit_error=True)

# List all actors
actors = ray.util.list_named_actors()
print("Named actors:", actors)

# Get all actor states (including unnamed ones)
# This is trickier - you might need to check the Ray dashboard or use a different approach
# Out:
# 2025-12-21 02:49:26,785	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-12-21 02:49:26,804	INFO worker.py:1821 -- Connecting to existing Ray cluster at address: 127.0.0.1:60453...
# 2025-12-21 02:49:26,808	INFO worker.py:1998 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# Named actors: []
# /Users/rajsingh/.pyenv/versions/3.10.12/envs/stem-splitter-app-env/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
